# %% [markdown]
# ## BioAgent for Metagenomics workflow
#
# ---
#
# > <br>
# > pip install genomeer
# > <br>
# > <br>

# %%
#!pip install -e .
# !curl http://10.52.88.30:11434/api/tags
# Out:
# {"models":[{"name":"gpt-oss:20b","model":"gpt-oss:20b","modified_at":"2025-09-08T11:38:49.018237787+01:00","size":13780173724,"digest":"aa4295ac10c3afb60e6d711289fc6896f5aef82258997b9efdaed6d0cc4cd8b8","details":{"parent_model":"","format":"gguf","family":"gptoss","families":["gptoss"],"parameter_size":"20.9B","quantization_level":"MXFP4"}},{"name":"qwen3:14b","model":"qwen3:14b","modified_at":"2025-05-15T23:15:30.994010178+01:00","size":9276198324,"digest":"7d7da67570e2be291ceb3fdcaf7b74566c2d0442981d69f0455e2143a7967073","details":{"parent_model":"","format":"gguf","family":"qwen3","families":["qwen3"],"parameter_size":"14.8B","quantization_level":"Q4_K_M"}}]}

# %% [markdown]
# ##### 1. Test

# %%
from genomeer.agent import BioAgent
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.30:11434/v1",
    api_key=None
)
# Out:
# ==================================================
# 🔧 BioAgent_v1 CONFIGURATION
# ==================================================
# 📋 DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ==================================================

# %%
agent.go('I wanna do sequence alignment, can you help me?')
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# I wanna do sequence alignment, can you help me?
# content='**Plan for Helping with Sequence Alignment**\n\n1. [ ] Ask the user for details about the sequences (DNA/RNA/protein, file format, whether they want pairwise or multiple alignment, and any specific tools or preferences).\n2. [ ] Based on the user’s preferences, propose a suitable alignment method and tools (e.g., `biopython` for pairwise, `MUSCLE` for multiple, `bowtie2` for large DNA datasets).\n3. [ ] Provide a concise, ready‑to‑run Python script (or shell commands) that performs the requested alignment, including installation steps if necessary.\n4. [ ] Explain how to interpret the output and any post‑processing steps.\n\n---\n\n**Step 1: Gather user requirements**\n\n<execute>\nprint("What type of sequences do you have? (DNA, RNA, Protein)")\nprint("Which file format are they in? (FASTA, FASTQ, etc.)")\nprint("Do you need pairwise alignment or multiple sequence alignment?")\nprint("Do you have any preferred tools or constraints (e.g., memory limits, speed)?")\n' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 448, 'prompt_tokens': 1212, 'total_tokens': 1660, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-oss:20b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-757', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None} id='run--e823ce00-9cf5-40ab-bc9a-ee3bc78551e8-0' usage_metadata={'input_tokens': 1212, 'output_tokens': 448, 'total_tokens': 1660, 'input_token_details': {}, 'output_token_details': {}}
# ================================== Ai Message ==================================
#
# **Plan for Helping with Sequence Alignment**
#
# 1. [ ] Ask the user for details about the sequences (DNA/RNA/protein, file format, whether they want pairwise or multiple alignment, and any specific tools or preferences).
# 2. [ ] Based on the user’s preferences, propose a suitable alignment method and tools (e.g., `biopython` for pairwise, `MUSCLE` for multiple, `bowtie2` for large DNA datasets).
# 3. [ ] Provide a concise, ready‑to‑run Python script (or shell commands) that performs the requested alignment, including installation steps if necessary.
# 4. [ ] Explain how to interpret the output and any post‑processing steps.
#
# ---
#
# **Step 1: Gather user requirements**
#
# <execute>
# print("What type of sequences do you have? (DNA, RNA, Protein)")
# print("Which file format are they in? (FASTA, FASTQ, etc.)")
# print("Do you need pairwise alignment or multiple sequence alignment?")
# print("Do you have any preferred tools or constraints (e.g., memory limits, speed)?")
# </execute>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent.go('I wanna do sequence alignment, can you help me?')
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/agent/BA1.py:1767, in BioAgent.go(self, prompt)
#    1764 config = {"recursion_limit": 500, "configurable": {"thread_id": 42}}
#    1765 self.log = []
# -> 1767 for s in self.app.stream(inputs, stream_mode="values", config=config):
#    1768     message = s["messages"][-1]
#    1769     out = pretty_print(message)
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2323, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2317     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2318     # computation proceeds in steps, while there are channel updates.
#    2319     # Channel updates from step N are only visible in step N+1
#    2320     # channels are guaranteed to be immutable for the duration of the step,
#    2321     # with channel updates applied only at the transition between steps.
#    2322     while loop.tick(input_keys=self.input_channels):
# -> 2323         for _ in runner.tick(
#    2324             loop.tasks.values(),
#    2325             timeout=self.step_timeout,
#    2326             retry_policy=self.retry_policy,
#    2327             get_waiter=get_waiter,
#    2328         ):
#    2329             # emit output
#    2330             yield from output()
#    2331 # emit output
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/site-packages/langgraph/pregel/runner.py:146, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     144 t = tasks[0]
#     145 try:
# --> 146     run_with_retry(
#     147         t,
#     148         retry_policy,
#     149         configurable={
#     150             CONFIG_KEY_CALL: partial(
#     151                 _call,
#     152                 weakref.ref(t),
#     153                 retry=retry_policy,
#     154                 futures=weakref.ref(futures),
#     155                 schedule_task=self.schedule_task,
#     156                 submit=self.submit,
#     157                 reraise=reraise,
#     158             ),
#     159         },
#     160     )
#     161     self.commit(t, None)
#     162 except Exception as exc:
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/site-packages/langgraph/utils/runnable.py:600, in RunnableSeq.invoke(self, input, config, **kwargs)
#     596 config = patch_config(
#     597     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     598 )
#     599 if i == 0:
# --> 600     input = step.invoke(input, config, **kwargs)
#     601 else:
#     602     input = step.invoke(input, config)
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/site-packages/langgraph/utils/runnable.py:365, in RunnableCallable.invoke(self, input, config, **kwargs)
#     363 else:
#     364     with set_config_context(config) as context:
# --> 365         ret = context.run(self.func, *args, **kwargs)
#     366 if isinstance(ret, Runnable) and self.recurse:
#     367     return ret.invoke(input, config)
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/agent/BA1.py:1313, in BioAgent.configure.<locals>.execute(state)
#    1309 # Otherwise, run as Python code
#    1310 else:
#    1311     # Inject custom functions into the Python execution environment
#    1312     self._inject_custom_functions_to_repl()
# -> 1313     result = run_with_timeout(run_python_code,
#    1314         args=[code],
#    1315         kwargs={"env_name": "bio-agent-env1"},
#    1316         timeout=timeout
#    1317     )
#    1319 if len(result) > 10000:
#    1320     result = (
#    1321         "The output is too long to be added to context. Here are the first 10K characters...\n"
#    1322         + result[:10000]
#    1323     )
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/utils/helper.py:239, in run_with_timeout(func, args, kwargs, timeout, cancel_event)
#     237 fut = ex.submit(func, *args, **kwargs)
#     238 try:
# --> 239     return fut.result(timeout=timeout)
#     240 except cf.TimeoutError as e:
#     241     if cancel_event is not None:
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/utils/helper.py:170, in run_python_code(code, env_name)
#     168 # --- Case 1: run in a micromamba environment ---
#     169 if env_name:
# --> 170     if not ensure_env(env_name, auto_install=True):
#     171         return f"Environment '{env_name}' is not available."
#     173     # Write the code to a temp file
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/runtime/env_manager.py:127, in ensure_env(name, auto_install)
#     124     return prefix, False, f"Environment '{name}' ready."
#     126 if auto_install:
# --> 127     with _install_lock(name):
#     128         if has_env(name):
#     129             return prefix, False, f"Environment '{name}' became ready."
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/runtime/env_manager.py:88, in _install_lock(name, timeout_sec)
#      86     time.sleep(1)
#      87 try:
# ---> 88     lock.touch()
#      89     yield
#      90 finally:
#
# File ~/anaconda3/envs/genomeer/lib/python3.11/pathlib.py:1108, in Path.touch(self, mode, exist_ok)
#    1106 if not exist_ok:
#    1107     flags |= os.O_EXCL
# -> 1108 fd = os.open(self, flags, mode)
#    1109 os.close(fd)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1.lock'
# During task with name 'execute' and id 'b58ba858-4137-af42-47a8-69c807e46cd0'
