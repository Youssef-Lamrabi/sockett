# %% [markdown]
# ## BioAgent for Metagenomics workflow
#
# ---
#
# > <br>
# > pip install genomeer
# > <br>
# > <br>

# %%
#!pip install -e .
# !curl http://10.52.88.30:11434/api/tags
# Out:
# {"models":[{"name":"gpt-oss:20b","model":"gpt-oss:20b","modified_at":"2025-09-08T11:38:49.018237787+01:00","size":13780173724,"digest":"aa4295ac10c3afb60e6d711289fc6896f5aef82258997b9efdaed6d0cc4cd8b8","details":{"parent_model":"","format":"gguf","family":"gptoss","families":["gptoss"],"parameter_size":"20.9B","quantization_level":"MXFP4"}},{"name":"qwen3:14b","model":"qwen3:14b","modified_at":"2025-05-15T23:15:30.994010178+01:00","size":9276198324,"digest":"7d7da67570e2be291ceb3fdcaf7b74566c2d0442981d69f0455e2143a7967073","details":{"parent_model":"","format":"gguf","family":"qwen3","families":["qwen3"],"parameter_size":"14.8B","quantization_level":"Q4_K_M"}}]}

# %% [markdown]
# ##### 1. Test

# %%
from genomeer.agent import BioAgent
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.30:11434/v1",
    api_key=None
)
# Out:
# ...
# 🔧 BioAgent_v1 CONFIGURATION
# ...
# 📋 DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ...

# %%
response = agent.go('hi')
# Out:
# Using prompt-based retrieval with the agent's LLM
# ***************************
# content='hi' additional_kwargs={} response_metadata={}
# ***************************
# ================================ Human Message =================================
#
# hi
# parsing error...
# ***************************
# content='Each response must include thinking process followed by either <execute> or <solution> tag. But there are no tags in the current response. Please follow the instruction, fix and regenerate the response again.' additional_kwargs={} response_metadata={}
# ***************************
# ================================ Human Message =================================
#
# Each response must include thinking process followed by either <execute> or <solution> tag. But there are no tags in the current response. Please follow the instruction, fix and regenerate the response again.
# ***************************
# ...

# %%
# ok - passed
#response = agent.go('I wanna do sequence alignment, can you help me?')

# %%
response = agent.go('can you execute this python code: caculate fibnacci of 2000')
# Out:
# Using prompt-based retrieval with the agent's LLM
# ***************************
# content='can you execute this python code: caculate fibnacci of 2000' additional_kwargs={} response_metadata={}
# ***************************
# ================================ Human Message =================================
#
# can you execute this python code: caculate fibnacci of 2000
# parsing error...
# ***************************
# content='Each response must include thinking process followed by either <execute> or <solution> tag. But there are no tags in the current response. Please follow the instruction, fix and regenerate the response again.' additional_kwargs={} response_metadata={}
# ***************************
# ================================ Human Message =================================
#
# ...

# %%
#response = agent.go('i want you tyo find all ORFs in this dna sequence: ATGGCTTCTACC CAA GAA TTT ATT CTG AAA GAT GGT GTT CCT TGG CGT CAA AAT CTG TAT TAA')
# Out:
# Using prompt-based retrieval with the agent's LLM
# content='i want you tyo find all ORFs in this dna sequence: ATGGCTTCTACC CAA GAA TTT ATT CTG AAA GAT GGT GTT CCT TGG CGT CAA AAT CTG TAT TAA' additional_kwargs={} response_metadata={}
# ================================ Human Message =================================
#
# i want you tyo find all ORFs in this dna sequence: ATGGCTTCTACC CAA GAA TTT ATT CTG AAA GAT GGT GTT CCT TGG CGT CAA AAT CTG TAT TAA
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 response = agent.go('i want you tyo find all ORFs in this dna sequence: ATGGCTTCTACC CAA GAA TTT ATT CTG AAA GAT GGT GTT CCT TGG CGT CAA AAT CTG TAT TAA')
#
# File ~/DATALAB/2025/Genomeer/genomeer/src/genomeer/agent/BA1.py:1886, in BioAgent.go(self, prompt)
#    1883 config = {"recursion_limit": 500, "configurable": {"thread_id": 42}}
# ...

# %%
response
# Out:
# (['================================\x1b Human Message \x1b=================================\n\ni want you tyo find all ORFs in this dna sequence: ATGGCTTCTACC CAA GAA TTT ATT CTG AAA GAT GGT GTT CCT TGG CGT CAA AAT CTG TAT TAA',
#   '================================\x1b Human Message \x1b=================================\n\nEach response must include thinking process followed by either <execute> or <solution> tag. But there are no tags in the current response. Please follow the instruction, fix and regenerate the response again.',
#   '================================\x1b Human Message \x1b=================================\n\nEach response must include thinking process followed by either <execute> or <solution> tag. But there are no tags in the current response. Please follow the instruction, fix and regenerate the response again.',
# ...

# %%
# from IPython.display import display, clear_output

# lines = []
# for step in agent.go_stream("can you execute this python code: calculate fibonacci of 2000"):
#     lines.append(step["output"])
#     clear_output(wait=True)
#     display("\n".join(lines))
