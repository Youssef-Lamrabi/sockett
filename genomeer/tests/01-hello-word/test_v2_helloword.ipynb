# %% [markdown]
# ### MetagenomicsAgent: hello word test case
# ---
# > pip install -e .
# >
# > pip install genomeer
# > <br>

# %%
from genomeer.agent.v2 import BioAgent

agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.105:11434/v1",
    api_key=None,
    auto_start_artifacts=True,
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Loaded environment variables from /home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/.env
#
# ...
# BioAgent_v1 CONFIGURATION
# ...
# DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ...
# INFO:     Started server process [117389]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8910 (Press CTRL+C to quit)
# Artifacts service on http://127.0.0.1:8910/docs
# INFO:     127.0.0.1:51526 - "POST /api/v1/artifacts/runs/create/cd4e39b4-f91a-42c2-9503-5ffa72402e7b HTTP/1.1" 200 OK
# ...

# %%
_ = agent.visualize_graph(mode="manual")
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	planner(planner)
# 	qa(qa)
# 	orchestrator(orchestrator)
# 	input_guard(input_guard)
# 	generator(generator)
# 	ensure_env(ensure_env)
# 	executor(executor)
# 	observer(observer)
# 	diagnostics(diagnostics)
# 	finalizer(finalizer)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> planner;
# 	finalizer --> __end__;
# 	generator --> ensure_env;
# 	qa --> __end__;
# 	planner -.-> qa;
# 	planner -.-> orchestrator;
# 	orchestrator -.-> planner;
# 	orchestrator -.-> input_guard;
# 	orchestrator -.-> finalizer;
# 	input_guard -.-> qa;
# 	input_guard -.-> generator;
# 	ensure_env -.-> executor;
# 	ensure_env -. &nbsp;end&nbsp; .-> __end__;
# 	executor -.-> observer;
# 	observer -.-> orchestrator;
# 	observer -.-> generator;
# 	observer -.-> diagnostics;
# 	diagnostics -.-> generator;
# 	diagnostics -. &nbsp;end&nbsp; .-> qa;
# 	ensure_env -.-> ensure_env;
# ...

# %% [markdown]
# <br>
# <b>Test: 1</b>

# %%
sid = "c390a7ed-b009-44b1-8516-34e3517c9749"

# %%
response = agent.go(
    """
    save a text file with inside "Hellow word" and give me link to download. formulate this as on step job only
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     save a text file with inside "Hellow word" and give me link to download. formulate this as on step job only
#
# ================================== Ai Message ==================================
#
# - [ ] Create a text file named `hello.txt` in the temporary directory (`$TEMP_DIR`) containing the line "Hellow word" and output the file path or download link to the user.
# <next:ORCHESTRATOR>
# ================================== Ai Message ==================================
#
# <running step=1/>
# <description>
# Create a text file named `hello.txt` in the temporary directory (`$TEMP_DIR`) containing the line "Hellow word" and output the file path or download link to the user.
# </description>
#
# Using prompt-based retrieval with the agent's LLM
# ================================== Ai Message ==================================
#
# <OK/>
# ...

# %%
response = agent.go(
    """
    What did we talk about previously?
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     What did we talk about previously?
#
# ================================== Ai Message ==================================
#
# <next:QA>
# ================================== Ai Message ==================================
#
# **Previous discussion**
#
# We carried out a simple file‑creation task:
#
# 1. **Action** – In the temporary working directory (`$TEMP_DIR`), a Python script was executed that created a file named `hello.txt`.
# 2. **Content** – The file contains a single line:
#    ```
#    Hellow word
#    ```
# 3. **Result** – The script printed the full path to the file, which now exists at:
#    ```
#    /tmp/bioagent/run-c390a7ed-b009-44b1-8516-34e3517c9749/hello.txt
#    ```
# 4. **Availability** – The file (and a bundle of all artifacts) is ready for download via the provided links.
#
# ...

# %% [markdown]
# <hr>
# <b style="color: green;">TEST 1: PASSED </b> - <b>DETAILS</b>: Agent carry out simplet test that require tool interaction with env as well as memory follow-up
# <hr>

# %% [markdown]
# <br>
# <b>Test: 2</b>

# %%
sid = "cd4e39b4-f91a-42c2-9503-5ffa72402e7b" # <-- new id for new session

# %%
response = agent.go(
    """
    I have this tiny sequence in the fasta file and I want to parse the whole sequence using k-mer, for k=2,3,4,5 
    and then compute different stats and organise this in table per k value
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     I have this tiny sequence in the fasta file and I want to parse the whole sequence using k-mer, for k=2,3,4,5
#     and then compute different stats and organise this in table per k value
#
# ================================== Ai Message ==================================
#
# <next:ORCHESTRATOR>
# - [ ] Load the FASTA file path (e.g., `input.fasta`) provided by the user.
# - [ ] For each k in `{2, 3, 4, 5}`:
#   - Run `kmer_profile(paths=[FASTA_PATH], k=k, canonical=True)` to generate a k‑mer count TSV (e.g., `k2.tsv`, `k3.tsv`, …) in the temp directory.
# - [ ] For each generated k‑mer TSV:
#   - Read the file and compute statistics:
#     - `total_kmers`: sum of all counts
#     - `unique_kmers`: number of distinct k‑mer rows
#     - `average_count`: mean count per k‑mer
#     - `max_count`: maximum count
#     - `min_count`: minimum count
# ...

# %%
response = agent.go(
    """
    Oops, sorry here is the fasta file
    """,
    attachments=["/home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/tests/01-hello-word/sequence_tiny.fasta"],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# [upload notice] New files: ['uploads/sequence_tiny.fasta']
# ================================== Ai Message ==================================
#
# <observe>Resuming with your new inputs…</observe>
# ================================== Ai Message ==================================
#
# <running step=1/>
# <description>
# Load the FASTA file path (e.g., `input.fasta`) provided by the user.
# </description>
#
# Using prompt-based retrieval with the agent's LLM
# ================================== Ai Message ==================================
#
# <OK/>
# <PRESENT>
# - fasta_file
# </PRESENT>
# ================================== Ai Message ==================================
#
# <EXECUTE>
# #!PY
# import os
# root_dir = '/tmp/bioagent/run-cd4e39b4-f91a-42c2-9503-5ffa72402e7b'
# fasta_path = os.path.join(root_dir, 'uploads', 'sequence_tiny.fasta')
# ...

# %% [markdown]
# <hr>
# <b style="color: green;">TEST 2: PASSED </b> - <b>DETAILS</b>: Agent can continue where he left even if input is missing
# <hr>
