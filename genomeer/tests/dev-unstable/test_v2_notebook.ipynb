# %% [markdown]
# ## BioAgent for Metagenomics workflow
#
# ---
#
# > <br>
# > pip install -e .
# >
# > pip install genomeer
# > <br>
# > <br>

# %%
#!python -m playwright install chromium
#!pip install playwright

# %%
from genomeer.agent.v2 import BioAgent

agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.30:11434/v1",
    api_key=None
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ...
# BioAgent_v1 CONFIGURATION
# ...
# DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ...

# %%
_ = agent.visualize_graph(mode="manual")
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	planner(planner)
# 	qa(qa)
# 	orchestrator(orchestrator)
# 	input_guard(input_guard)
# 	generator(generator)
# 	ensure_env(ensure_env)
# 	executor(executor)
# 	observer(observer)
# 	diagnostics(diagnostics)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> planner;
# 	generator --> ensure_env;
# 	qa --> __end__;
# 	planner -.-> qa;
# 	planner -.-> orchestrator;
# 	orchestrator -.-> planner;
# 	orchestrator -.-> input_guard;
# 	input_guard -.-> qa;
# 	input_guard -.-> generator;
# 	ensure_env -.-> executor;
# 	ensure_env -. &nbsp;end&nbsp; .-> __end__;
# 	executor -.-> observer;
# 	observer -.-> orchestrator;
# 	observer -.-> generator;
# 	observer -.-> diagnostics;
# 	diagnostics -.-> generator;
# 	diagnostics -. &nbsp;end&nbsp; .-> qa;
# 	ensure_env -.-> ensure_env;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# ...

# %% [markdown]
# <br>
# <b>Test: 1</b>

# %%
response = agent.go('Hi BioAgent, how can you help me?')
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# Hi BioAgent, how can you help me?
# ================================== Ai Message ==================================
#
# <next:QA>
# ================================== Ai Message ==================================
#
# Hi there! I’m BioAgent, a versatile bio‑informatics assistant that can help you with almost every step of a typical genomics workflow. Here’s a quick rundown of what I can do:
#
# | Area | What I can do for you | How it helps |
# |------|-----------------------|--------------|
# | **Data ingestion** | Load FASTA/FASTQ files, convert formats, and subsample reads | Get your raw data into a tidy, usable form |
# | **Quality control** | Compute simple QC metrics (read count, avg length, GC%, Ns) and trim/adapters | Spot problems early and clean the data |
# ...

# %% [markdown]
# <hr>
# <b style="color: green;">TEST 1: PASSED </b> - <b>DETAILS</b>: Transition from PLanner agent to QA agent on simple request.
# <hr>

# %% [markdown]
# <br>
# <b>Test: 2</b>

# %%
response = agent.go("""
I wanna identify all the ORFs in this genome from NCBI: {GCA_000001735.2	GCF_000001735.4 Arabidopsis thaliana (thale cress)	Columbia (ecotype)}
And compute the distribution of the length  of those orf and display on a graph so I can download. I just want branstorming. I wanna khow if i have to do it howx to proceed steps by steps. I'm not looking for you to do it now. just how can i schedule such a task?
""")
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
# I wanna identify all the ORFs in this genome from NCBI: {GCA_000001735.2	GCF_000001735.4 Arabidopsis thaliana (thale cress)	Columbia (ecotype)}
# And compute the distribution of the length  of those orf and display on a graph so I can download. I just want branstorming. I wanna khow if i have to do it howx to proceed steps by steps. I'm not looking for you to do it now. just how can i schedule such a task?
#
# ================================== Ai Message ==================================
#
# <next:ORCHESTRATOR>
# - [ ] Download the reference genome FASTA for accession **GCF_000001735.4** from NCBI (e.g., `ncbi-genome-download --format fasta GCF_000001735.4`).
# - [ ] Verify the downloaded FASTA (check header, size, integrity).
# ...

# %% [markdown]
# <hr>
# <b style="color: green;">TEST 2: PASSED </b> - <b>DETAILS</b>: Distiguish enough between planning and question-answer
# <hr>

# %% [markdown]
# <br>
# <b>Test: 3</b>

# %%
response = agent.go("""
I wanna identify all the ORFs in this genome from NCBI: {GCA_000001735.2	GCF_000001735.4 Arabidopsis thaliana (thale cress)	Columbia (ecotype)}
And compute the distribution of the length  of those orf and display on a graph so I can download.
""")
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
# I wanna identify all the ORFs in this genome from NCBI: {GCA_000001735.2	GCF_000001735.4 Arabidopsis thaliana (thale cress)	Columbia (ecotype)}
# And compute the distribution of the length  of those orf and display on a graph so I can download.
#
# ================================== Ai Message ==================================
#
# <next:ORCHESTRATOR>
# - [ ] Use `ncbi-genome-download -t 1000 -l complete -F fasta -o $TEMP_DIR/genome --taxids 3702` to download the reference Arabidopsis thaliana genome (GCF_000001735.4) into `$TEMP_DIR/genome`.
# - [ ] Find the downloaded FASTA file path (e.g., `$TEMP_DIR/genome/GCF_000001735.4*.fna`) and store it as `genome_fasta`.
# - [ ] Run `translate_orfs` on `genome_fasta` with `min_aa=30` and `strand="both"` to generate a TSV of ORFs (`orfs.tsv`).
#   ```python
# ...

# %% [markdown]
# <hr>
# <b style="color: blue;">TEST 3: PENDING </b> - <b>DETAILS</b>: Run first workflow: plan-execute-summary
# <hr>

# %%
Find ORFs in GCF_000001735.4 and plot their length distribution.

# %%
*****

# %%
response = agent.go('What can you help me with in terms of visualization tasks?')

# %%
response = agent.go('i wanna Visualize k‑mer spectra to assess sequencing error rates, repeat content, or genome complexity.')

# %%
X = "TES TEST {abc}"
X = X.format(**{"abc": "test"})
X
