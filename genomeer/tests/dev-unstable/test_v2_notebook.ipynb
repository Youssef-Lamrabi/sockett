# %% [markdown]
# ## BioAgent for Metagenomics workflow
#
# ---
#
# > <br>
# > pip install -e .
# >
# > pip install genomeer
# > <br>
# > <br>

# %%
#!python -m playwright install chromium
#!pip install playwright

# %%
import genomeer
genomeer.__version__
# Out:
# '0.0.3'

# %%
from genomeer.agent.v2 import BioAgent

agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.30:11434/v1",
    api_key=None,
    auto_start_artifacts=True,
    interaction_mode="feedback"
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Loaded environment variables from /home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/.env
#
# ...
# BioAgent_v1 CONFIGURATION
# ...
# DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ...
# INFO:     Started server process [77043]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8910 (Press CTRL+C to quit)
# Artifacts service on http://127.0.0.1:8910/docs

# %%
_ = agent.visualize_graph(mode="manual")
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	planner(planner)
# 	qa(qa)
# 	orchestrator(orchestrator)
# 	input_guard(input_guard)
# 	generator(generator)
# 	ensure_env(ensure_env)
# 	executor(executor)
# 	observer(observer)
# 	diagnostics(diagnostics)
# 	finalizer(finalizer)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> planner;
# 	finalizer --> __end__;
# 	qa --> __end__;
# 	planner -.-> qa;
# 	planner -.-> orchestrator;
# 	planner -.-> generator;
# 	planner -.-> ensure_env;
# 	planner -.-> input_guard;
# 	orchestrator -.-> planner;
# 	orchestrator -.-> input_guard;
# 	orchestrator -.-> finalizer;
# 	input_guard -.-> qa;
# 	input_guard -.-> generator;
# 	generator -.-> ensure_env;
# 	generator -.-> qa;
# 	ensure_env -.-> executor;
# 	ensure_env -. &nbsp;end&nbsp; .-> __end__;
# 	executor -.-> observer;
# 	observer -.-> orchestrator;
# 	observer -.-> generator;
# 	observer -.-> diagnostics;
# 	observer -.-> qa;
# ...

# %% [markdown]
# <br>
# <b>Test: 1</b>

# %%
sid = "feedback-session-test-940d-e713b32fc96e"
response = agent.go(
    """
    I wanna identify all the ORFs in the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4)
    And compute the distribution of the length  of those orf and display on a graph so I can download.
    """,
    attachments=[],
    session_id=sid # <-- leave it empty for standalone session
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     I wanna identify all the ORFs in the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4)
#     And compute the distribution of the length  of those orf and display on a graph so I can download.
#
# ================================== Ai Message ==================================
#
# <review>
# PLAN READY ✅
#
# Proposed steps:
# - 1. Download the Arabidopsis thaliana (Columbia ecotype) genome GCF_000001735.4 FASTA using `ncbi-genome-download` (output to temp dir).
# - 2. Run `translate_orfs` on the downloaded FASTA to identify all ORFs (min_aa=30, genetic_code=11, strand='both') and capture the ORF coordinates and protein sequences.
# - 3. Extract the ORF amino‑acid lengths from the translation output and compute their distribution (e.g., histogram bins).
# ...

# %%
response = agent.go(
    """
    It's okay continue
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     It's okay continue
#
# ================================== Ai Message ==================================
#
# <observe>Resuming after your approval…</observe>
# ================================== Ai Message ==================================
#
# <running step=1/>
# <description>
# Download the Arabidopsis thaliana (Columbia ecotype) genome GCF_000001735.4 FASTA using `ncbi-genome-download` (output to temp dir).
# </description>
#
# Using prompt-based retrieval with the agent's LLM
# ================================== Ai Message ==================================
#
# <OK/>
# <PRESENT>
# - accession_id
# </PRESENT>
# ================================== Ai Message ==================================
#
# <review>
# CODE PROPOSED TO EXECUTE THIS STEP
#
# <EXECUTE>
# #!PY
# import os
# from genomeer.tools.function.ncbi import download_from_ncbi
#
# ...

# %%
response = agent.go(
    """
    i dont wanna use this function from ncbi, 
    use url instead "https://ftp.ncbi.nlm.nih.gov/genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1/"
    On the page i foudnthose ifnromation taht may help you :
    
    Index of /genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1
    Name                                                                 Last modified      Size  
    Parent Directory                                                                          -   
    GCF_000001735.4_TAIR10.1_assembly_structure/                         2024-06-08 04:54    -   
    GCF_000001735.4_TAIR10.1_assembly_report.txt                         2019-03-06 02:33  1.7K  
    GCF_000001735.4_TAIR10.1_assembly_stats.txt                          2022-10-20 17:51   14K  
    GCF_000001735.4_TAIR10.1_cds_from_genomic.fna.gz                     2022-10-20 17:51   14M  
    GCF_000001735.4_TAIR10.1_fcs_report.txt                              2024-08-23 09:12  504   
    GCF_000001735.4_TAIR10.1_feature_count.txt                           2024-06-08 04:54  3.5K  
    GCF_000001735.4_TAIR10.1_feature_table.txt.gz                        2022-10-20 17:51  3.1M  
    GCF_000001735.4_TAIR10.1_genomic.fna.gz                              2023-06-16 16:44   36M  
    GCF_000001735.4_TAIR10.1_genomic.gbff.gz                             2023-06-16 16:44   78M  
    GCF_000001735.4_TAIR10.1_genomic.gff.gz                              2023-06-16 16:44   21M  
    GCF_000001735.4_TAIR10.1_genomic.gtf.gz                              2023-06-16 16:44   37M  
    GCF_000001735.4_TAIR10.1_genomic_gaps.txt.gz                         2019-03-06 02:33  1.0K  
    GCF_000001735.4_TAIR10.1_protein.faa.gz                              2022-10-20 17:51   11M  
    GCF_000001735.4_TAIR10.1_protein.gpff.gz                             2023-06-16 16:44   44M  
    GCF_000001735.4_TAIR10.1_rna.fna.gz                                  2022-10-20 17:51   24M  
    GCF_000001735.4_TAIR10.1_rna.gbff.gz                                 2023-06-16 16:44   83M  
    GCF_000001735.4_TAIR10.1_rna_from_genomic.fna.gz                     2023-06-16 16:44   24M  
    GCF_000001735.4_TAIR10.1_translated_cds.faa.gz                       2022-10-20 17:51  9.9M  
    README.txt                                                           2024-08-27 13:56   55K  
    annotation_hashes.txt                                                2024-06-08 04:54  410   
    assembly_status.txt                                                  2025-10-03 01:34   14   
    md5checksums.txt                                                     2024-10-21 18:14  3.5K  
    uncompressed_checksums.txt                                           2025-03-07 14:01  2.0K  
    HHS Vulnerability Disclosure
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     i dont wanna use this function from ncbi,
#     use url instead "https://ftp.ncbi.nlm.nih.gov/genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1/"
#     On the page i foudnthose ifnromation taht may help you :
#
#     Index of /genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1
#     Name                                                                 Last modified      Size
#     Parent Directory                                                                          -
#     GCF_000001735.4_TAIR10.1_assembly_structure/                         2024-06-08 04:54    -
#     GCF_000001735.4_TAIR10.1_assembly_report.txt                         2019-03-06 02:33  1.7K
#     GCF_000001735.4_TAIR10.1_assembly_stats.txt                          2022-10-20 17:51   14K
# ...

# %%
response = agent.go(
    """
    i dont wanna use this function "from genomeer.tools.function.ncbi import download_from_ncbi", 
    use url instead "https://ftp.ncbi.nlm.nih.gov/genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1/"
    On thIS WEBPAGE page i found those information that may help you. VERY IMPORTANT I N YOU FIX: I WANNA USE URL BASE ÙETHOD FOR DOWNLOADIGNTHE SEAUSCE :
    
    Index of /genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1
    Name                                                                 Last modified      Size  
    Parent Directory                                                                          -   
    GCF_000001735.4_TAIR10.1_assembly_structure/                         2024-06-08 04:54    -   
    GCF_000001735.4_TAIR10.1_assembly_report.txt                         2019-03-06 02:33  1.7K  
    GCF_000001735.4_TAIR10.1_assembly_stats.txt                          2022-10-20 17:51   14K  
    GCF_000001735.4_TAIR10.1_cds_from_genomic.fna.gz                     2022-10-20 17:51   14M  
    GCF_000001735.4_TAIR10.1_fcs_report.txt                              2024-08-23 09:12  504   
    GCF_000001735.4_TAIR10.1_feature_count.txt                           2024-06-08 04:54  3.5K  
    GCF_000001735.4_TAIR10.1_feature_table.txt.gz                        2022-10-20 17:51  3.1M  
    GCF_000001735.4_TAIR10.1_genomic.fna.gz                              2023-06-16 16:44   36M  
    GCF_000001735.4_TAIR10.1_genomic.gbff.gz                             2023-06-16 16:44   78M  
    GCF_000001735.4_TAIR10.1_genomic.gff.gz                              2023-06-16 16:44   21M  
    GCF_000001735.4_TAIR10.1_genomic.gtf.gz                              2023-06-16 16:44   37M  
    GCF_000001735.4_TAIR10.1_genomic_gaps.txt.gz                         2019-03-06 02:33  1.0K  
    GCF_000001735.4_TAIR10.1_protein.faa.gz                              2022-10-20 17:51   11M  
    GCF_000001735.4_TAIR10.1_protein.gpff.gz                             2023-06-16 16:44   44M  
    GCF_000001735.4_TAIR10.1_rna.fna.gz                                  2022-10-20 17:51   24M  
    GCF_000001735.4_TAIR10.1_rna.gbff.gz                                 2023-06-16 16:44   83M  
    GCF_000001735.4_TAIR10.1_rna_from_genomic.fna.gz                     2023-06-16 16:44   24M  
    GCF_000001735.4_TAIR10.1_translated_cds.faa.gz                       2022-10-20 17:51  9.9M  
    README.txt                                                           2024-08-27 13:56   55K  
    annotation_hashes.txt                                                2024-06-08 04:54  410   
    assembly_status.txt                                                  2025-10-03 01:34   14   
    md5checksums.txt                                                     2024-10-21 18:14  3.5K  
    uncompressed_checksums.txt                                           2025-03-07 14:01  2.0K  
    HHS Vulnerability Disclosure
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     i dont wanna use this function "from genomeer.tools.function.ncbi import download_from_ncbi",
#     use url instead "https://ftp.ncbi.nlm.nih.gov/genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1/"
#     On thIS WEBPAGE page i found those information that may help you. VERY IMPORTANT I N YOU FIX: I WANNA USE URL BASE ÙETHOD FOR DOWNLOADIGNTHE SEAUSCE :
#
#     Index of /genomes/refseq/plant/Arabidopsis_thaliana/latest_assembly_versions/GCF_000001735.4_TAIR10.1
#     Name                                                                 Last modified      Size
#     Parent Directory                                                                          -
#     GCF_000001735.4_TAIR10.1_assembly_structure/                         2024-06-08 04:54    -
# ...

# %%
response = agent.go(
    """
    NICE WE CAN PROCEED
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     NICE WE CAN PROCEED
#
# ================================== Ai Message ==================================
#
# <observe>Resuming after your approval…</observe>
# ================================== Ai Message ==================================
#
# <observe>Environment 'bio-agent-env1' ready at /home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1</observe>
# ---------------------------------
# ['/home/biolab-office-1/.bioagentpkg/runtime/pkgs/bin/micromamba', 'run', '-p', '/home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1', 'python', '/home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/tests/dev-unstable/.genomeer_runs/tmpdr7bh862.py']
# ---------------------------------
# ================================== Ai Message ==================================
#
# ...

# %%
response = agent.go(
    """
    okay
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     okay
#
# ================================== Ai Message ==================================
#
# <observe>Resuming after your approval…</observe>
# ================================== Ai Message ==================================
#
# <observe>Environment 'bio-agent-env1' ready at /home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1</observe>
# ---------------------------------
# ['/home/biolab-office-1/.bioagentpkg/runtime/pkgs/bin/micromamba', 'run', '-p', '/home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1', 'python', '/home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/tests/dev-unstable/.genomeer_runs/tmp53rdt9rq.py']
# ---------------------------------
# ================================== Ai Message ==================================
#
# <observe>Code Execution output:  'Error running this script
# ...

# %%
response = agent.go(
    """
    let's go
    """,
    attachments=[],
    session_id=sid
)
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
#     let's go
#
# ================================== Ai Message ==================================
#
# <observe>Resuming after your approval…</observe>
# ================================== Ai Message ==================================
#
# <observe>Environment 'bio-agent-env1' ready at /home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1</observe>
# ---------------------------------
# ['/home/biolab-office-1/.bioagentpkg/runtime/pkgs/bin/micromamba', 'run', '-p', '/home/biolab-office-1/.bioagentpkg/runtime/pkgs/envs/bio-agent-env1', 'python', '/home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/tests/dev-unstable/.genomeer_runs/tmpyn8gjkcv.py']
# ---------------------------------
# ================================== Ai Message ==================================
#
# <observe>Code Execution output:  'Error running this script
# ...

# %% [markdown]
# <hr>
# <b style="color: green;">TEST 1: PASSED </b> - <b>DETAILS</b>: ---
# <hr>
