# %% [markdown]
# ## MetagenomicsAgent: NCBI Viz test case
# ---
#
# > <br>
# > pip install -e .
# >
# > pip install genomeer
# > <br>
# > <br>

# %%
from genomeer.agent.v2 import BioAgent

agent = BioAgent(path="./data",
    llm="gpt-oss:20b",
    source="Custom",
    use_tool_retriever=True,
    timeout_seconds=600,
    base_url="http://10.52.88.30:11434/v1",
    api_key=None
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Loaded environment variables from /home/biolab-office-1/DATALAB/2025/Genomeer/genomeer/.env
#
# ...
# BioAgent_v1 CONFIGURATION
# ...
# DEFAULT CONFIG :
#   Path: ./data
#   Run Dir: .genomeer_runs
#   Timeout Seconds: 600
#   Llm: ollama/llama3.1
#   Temperature: 0.7
#   Use Tool Retriever: True
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gpt-oss:20b
#   Source: Custom
#   Base URL: http://10.52.88.30:11434/v1
# ...

# %%
_ = agent.visualize_graph(mode="manual")
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	planner(planner)
# 	qa(qa)
# 	orchestrator(orchestrator)
# 	input_guard(input_guard)
# 	generator(generator)
# 	ensure_env(ensure_env)
# 	executor(executor)
# 	observer(observer)
# 	diagnostics(diagnostics)
# 	finalizer(finalizer)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> planner;
# 	finalizer --> __end__;
# 	generator --> ensure_env;
# 	qa --> __end__;
# 	planner -.-> qa;
# 	planner -.-> orchestrator;
# 	orchestrator -.-> planner;
# 	orchestrator -.-> input_guard;
# 	orchestrator -.-> finalizer;
# 	input_guard -.-> qa;
# 	input_guard -.-> generator;
# 	ensure_env -.-> executor;
# 	ensure_env -. &nbsp;end&nbsp; .-> __end__;
# 	executor -.-> observer;
# 	observer -.-> orchestrator;
# 	observer -.-> generator;
# 	observer -.-> diagnostics;
# 	diagnostics -.-> generator;
# 	diagnostics -. &nbsp;end&nbsp; .-> qa;
# 	ensure_env -.-> ensure_env;
# ...

# %% [markdown]
# <br>
# <b>Test: 3</b>

# %%
x="""
I wanna identify all the ORF(open reading frame) in the Arabidopsis thaliana (Columbia ecotype) genome 
from NCBI (accessions: GCA_000001735.2 and GCF_000001735.4) in order to compute their length distribution and 
generate a plot of the distribution, and provide the plot in a downloadable format.

--
I wanna identify all the ORFs in this genome from NCBI: {GCA_000001735.2	GCF_000001735.4 Arabidopsis thaliana (thale cress)	Columbia (ecotype)}
And compute the distribution of the length  of those orf and display on a graph so I can download.

I wanna download the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4) and then calculate GC% in sliding windows, 
and provide both a TSV of the results and a line plot as downloadable files.
"""

# %%
response = agent.go("""
I wanna identify all the ORFs in the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4)
And compute the distribution of the length  of those orf and display on a graph so I can download.
""")
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
#
# I wanna identify all the ORFs in the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4)
# And compute the distribution of the length  of those orf and display on a graph so I can download.
#
# ================================== Ai Message ==================================
#
# <next:ORCHESTRATOR>
# - [ ] Download the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4) FASTA from NCBI to a temporary folder using `ncbi-genome-download` with parameters: `groups="plant"`, `assembly_accessions="GCF_000001735.4"`, `formats="fasta"`, `output_folder` set to the temp directory.
# - [ ] Load the downloaded FASTA into a lightweight TSV using `load_sequences` from `genomeer.tools.function.basic`.
# ...

# %%
#response = agent.go("""
#I wanna identify all the ORFs in the Arabidopsis thaliana (Columbia ecotype) genome (GCF_000001735.4)
#And compute the distribution of the length  of those orf and display on a graph so I can download.
#""")

# %% [markdown]
# <hr>
# <b style="color: blue;">TEST 3: PENDING </b> - <b>DETAILS</b>: Run first workflow: plan-execute-summary
# <hr>
