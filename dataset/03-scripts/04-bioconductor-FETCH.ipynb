# %% [markdown]
# #### **Bioconductor -- FETCH**

# %%
#!pip install requests beautifulsoup4

# %%
import re, time, json, csv, html
from pathlib import Path
from urllib.parse import urlencode
from functools import lru_cache
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import random

# %%
# ========================
# Paths & output
# ========================
TAGS_PATH  = Path("../02-datasource/bioconductor_tags_[filtered].json")
OUT_DIR    = Path("../04-output/raw/bioconductor")
OUT_DIR.mkdir(parents=True, exist_ok=True)

JSONL_PATH = OUT_DIR / "bioconductor_metagenomics_tag.jsonl"
CSV_PATH   = OUT_DIR / "bioconductor_metagenomics_tag.csv"
CACHE_IDS  = OUT_DIR / "seen_ids_tag.txt"

HEADERS = {
    "User-Agent": "MetagenomicsCollector/1.3 (+research; contact: genereux.akotenou@gmail.com)"
}

# ========================
# Crawl config
# ========================
SLEEP_BETWEEN_REQUESTS = 1.1

# Order variants to fetch per tag (exactly one page each)
# - 'creation'   : newest first (recent)
# - 'rank'       : most interesting
# - 'votes'      : most upvoted
# - 'replies'    : most replied
ORDER_VARIANTS = ["creation", "rank", "votes", "replies"]

# %%
# ========================
# Small helpers
# ========================
def sleep():
    # time.sleep(SLEEP_BETWEEN_REQUESTS)
    time.sleep(SLEEP_BETWEEN_REQUESTS + random.uniform(0, 0.6))

SESSION = requests.Session()
retry = Retry(
    total=8,                # overall retries
    connect=4,              # connection-level retries
    read=4,                 # read timeouts
    backoff_factor=1.2,     # exponential backoff: 1.2, 2.4, 4.8, ...
    status_forcelist=(429, 500, 502, 503, 504),
    allowed_methods=frozenset(["GET"]),
    raise_on_status=False,
)
adapter = HTTPAdapter(max_retries=retry, pool_connections=100, pool_maxsize=100)
SESSION.mount("https://", adapter)
SESSION.mount("http://", adapter)

def load_seen_ids():
    if CACHE_IDS.exists():
        return set(x.strip() for x in CACHE_IDS.read_text().splitlines() if x.strip())
    return set()

def save_seen_ids(ids):
    with open(CACHE_IDS, "w", encoding="utf-8") as f:
        for pid in sorted(ids, key=lambda x: int(x)):
            f.write(f"{pid}\n")

# def fetch(url, as_json=False, params=None):
#     r = requests.get(url, headers=HEADERS, params=params, timeout=30)
#     r.raise_for_status()
#     return r.json() if as_json else r.text
def fetch(url, as_json=False, params=None, timeout=(5, 60)):
    """
    Robust fetch with retries/backoff. timeout=(connect, read)
    """
    for attempt in range(1, 6):
        try:
            r = SESSION.get(url, headers=HEADERS, params=params, timeout=timeout)
            r.raise_for_status()
            return r.json() if as_json else r.text
        except requests.exceptions.RequestException as e:
            if attempt == 5:
                # give up after 5 explicit tries (Retry may have already retried inside)
                raise
            delay = min(15, (2 ** attempt) * 0.8) + random.uniform(0, 0.5)
            print(f"[retry] {type(e).__name__}: {e} — sleeping {delay:.1f}s then retrying")
            time.sleep(delay)

def html_plain_text(xhtml):
    try:
        return BeautifulSoup(xhtml or "", "html.parser").get_text("\n", strip=True)
    except Exception:
        return (xhtml or "").strip()

def as_int_or_str(x):
    try:
        return int(x)
    except Exception:
        return str(x)

def normalize_tags(tag_val, fallback=None):
    # API returns space-separated string; sometimes list
    if isinstance(tag_val, list):
        return [t for t in tag_val if t]
    if isinstance(tag_val, str):
        toks = [t.strip() for t in tag_val.split() if t.strip()]
        if toks:
            return toks
    return list(fallback) if fallback else []

def get_body_text(post_json: dict) -> str:
    # Biostars uses 'xhtml' or 'content'
    html_blob = post_json.get("xhtml") or post_json.get("content") or ""
    return html_plain_text(html_blob)

# Keep everything in tag-only mode
def apply_labels_from_config(_text): return []
def blocked_by_global_excludes(_text): return False

# ========================
# Read list of tags
# ========================
def load_tags_list(path: Path):
    if path.exists():
        try:
            tags = json.loads(path.read_text(encoding="utf-8"))
            tags = [t.strip() for t in tags if isinstance(t, str) and t.strip()]
            if tags:
                return tags
        except Exception as e:
            print(f"[warn] failed to read {path}: {e}")
    # fallback to your example list
    return ["rna-seq", "metagenomics", "microbiome", "shotgun-metagenomics", "16s", "assembly", "binning"]

TAGS = load_tags_list(TAGS_PATH)
print(f"Loaded {len(TAGS)} tags.")

# ========================
# Tag URLs (single page per order)
# ========================
def tag_order_urls(tag):
    base = f"https://support.bioconductor.org/tag/{tag}/"
    for order in ORDER_VARIANTS:
        yield f"{base}?order={order}", order

def extract_post_ids_from_index(html_text):
    soup = BeautifulSoup(html_text, "html.parser")
    ids = set()
    for a in soup.find_all("a", href=True):
        m = re.search(r"/p/(\d+)/?", a["href"])
        if m:
            ids.add(m.group(1))
    return ids
# Out:
# Loaded 43 tags.

# %%
# ========================
# API helpers
# ========================
@lru_cache(maxsize=8192)
def get_post_json(pid):
    return fetch(f"https://support.bioconductor.org/api/post/{pid}/", as_json=True)

@lru_cache(maxsize=4096)
def get_user_json(uid):
    """Fetch Biostars user profile once; cached."""
    if uid in (None, ""):
        return {}
    try:
        return fetch(f"https://support.bioconductor.org/api/user/{uid}/", as_json=True)
    except Exception:
        return {}

def compact_user_profile(u):
    if not u:
        return None
    return {
        "id": u.get("id"),
        "name": u.get("name"),
        "date_joined": u.get("date_joined"),
        "last_login": u.get("last_login"),
        "joined_days_ago": u.get("joined_days_ago"),
        # votes GIVEN by the user
        "vote_count": u.get("vote_count"),
    }

def make_author_obj(name, uid):
    """Return merged author object with profile fields (uid may be str)."""
    if uid in (None, ""):
        return {
            "id": None, "name": name, "date_joined": None,
            "last_login": None, "vote_count": None, "joined_days_ago": None
        }
    uid_norm = as_int_or_str(uid)
    prof_raw = compact_user_profile(get_user_json(uid_norm)) or {}
    return {
        "id": uid_norm,
        "name": name,
        "date_joined": prof_raw.get("date_joined"),
        "last_login": prof_raw.get("last_login"),
        "joined_days_ago": prof_raw.get("joined_days_ago"),
        "vote_count": prof_raw.get("vote_count"),
    }

# ========================
# HTML: enumerate answers & accepted
# ========================
def extract_answer_ids_and_accept_flag(soup):
    """
    Return (answer_ids, accepted_id) from a Biostars thread HTML.
    - Each answer is under: div.post.view.open[data-value]
    - Accepted answer body has itemprop="acceptedAnswer"
    - Other answers use itemprop="suggestedAnswer"
    """
    ans_ids, accepted_id = [], None
    for block in soup.select('div.post.view.open[data-value]'):
        pid = block.get("data-value")
        if not pid:
            continue
        body = block.select_one(
            'div.body[itemprop="acceptedAnswer"], div.body[itemprop="suggestedAnswer"]'
        )
        if body:
            ans_ids.append(pid)
            if body.get("itemprop") == "acceptedAnswer":
                accepted_id = pid
    return ans_ids, accepted_id

# ========================
# Thread parsing (API + HTML) incl. user profiles
# ========================
def parse_thread_page(pid):
    """
    - Use HTML to enumerate answer IDs and detect accepted answer.
    - Use API to get clean bodies & metadata.
    - Merge author (id/name + profile fields) into a single object.
    """
    url = f"https://support.bioconductor.org/p/{pid}/"
    soup = BeautifulSoup(fetch(url), "html.parser")

    # Title
    title_el = soup.select_one('div.post.view .title[itemprop="name"]') or soup.select_one("div.title")
    title = title_el.get_text(strip=True) if title_el else ""

    # Question via API
    q_json = get_post_json(pid)
    q_text = get_body_text(q_json) or ""
    if not q_text.strip():
        q_html_el = soup.select_one('[itemprop="mainEntity"] [itemprop="text"]')
        if q_html_el:
            q_text = q_html_el.get_text("\n", strip=True)

    q_created_at  = q_json.get("creation_date")
    q_author_uid  = q_json.get("author_uid") or q_json.get("author_id")
    q_author_name = q_json.get("author")
    q_author      = make_author_obj(q_author_name, q_author_uid)

    # Tags
    tags_api  = normalize_tags(q_json.get("tag_val"))
    tags_html = [a.get_text(strip=True) for a in soup.select("span.inplace-tags a.ptag")]

    # Answers
    ans_ids, accepted_id = extract_answer_ids_and_accept_flag(soup)
    answers = []
    for aid in ans_ids:
        a_json = get_post_json(aid)
        a_text = get_body_text(a_json)
        if not a_text or len(a_text) < 20:
            continue

        a_author_uid  = a_json.get("author_uid") or a_json.get("author_id")
        a_author_name = a_json.get("author")
        a_author      = make_author_obj(a_author_name, a_author_uid)

        answers.append({
            "answer_id": as_int_or_str(aid),
            "text": a_text,
            "score": int(a_json.get("vote_count", 0) or 0),
            "accepted": (str(aid) == str(accepted_id)),
            "created_at": a_json.get("creation_date"),
            "author": a_author,
        })

    # Pick best: accepted > highest score > longer
    best = None
    if answers:
        acc = [a for a in answers if a["accepted"]]
        best = (sorted(acc, key=lambda x: (x["score"], len(x["text"])), reverse=True)[0]
                if acc else sorted(answers, key=lambda x: (x["score"], len(x["text"])), reverse=True)[0])

    return {
        "url": url,
        "title": title,
        "question_text": q_text,
        "question_created_at": q_created_at,
        "question_author": q_author,           # merged object
        "answers": answers,                    # each with merged author
        "best_answer": best,
        "tags_api": tags_api,
        "tags_html": tags_html,
    }

# ========================
# Normalizer (adds answers_all, origin tag + order)
# ========================
def normalize_record(pid, thread_meta, post_json, origin_tag="", order_variant=""):
    q = (thread_meta.get("question_text") or "").strip()
    a_best = (thread_meta.get("best_answer", {}) or {}).get("text", "").strip()
    if not q or not a_best:
        return None

    tags_site = normalize_tags(
        post_json.get("tag_val"),
        fallback=(thread_meta.get("tags_api") or thread_meta.get("tags_html") or [])
    )

    full_text = " ".join([thread_meta.get("title",""), q, a_best, " ".join(tags_site)])
    if blocked_by_global_excludes(full_text):
        return None
    labels = apply_labels_from_config(full_text)

    return {
        "source": "biostars",
        "post_id": as_int_or_str(pid),
        "url": thread_meta["url"],
        "title": thread_meta.get("title", ""),
        "search_query": origin_tag,           # keep legacy field name
        "crawl_tag": origin_tag,              # explicit
        "crawl_order": order_variant,         # NEW: which order produced this

        # Question (author merged)
        "question": q,
        "question_created_at": thread_meta.get("question_created_at"),
        "question_author": thread_meta.get("question_author"),

        # Answers
        "answer": a_best,
        "answers_all": thread_meta.get("answers", []),
        "accepted": bool(thread_meta.get("best_answer", {}).get("accepted", False)),
        "score": int(thread_meta.get("best_answer", {}).get("score", 0) or 0),

        # Site/meta
        "tags_site": tags_site,
        "created_at": post_json.get("creation_date"),
        "has_accepted": post_json.get("has_accepted", False),
        "view_count": post_json.get("view_count", 0),

        # Auto-labels (empty)
        "topic_labels": labels,
    }

# %%
# ========================
# Crawl (by tag, one page per order)
# ========================
from collections import defaultdict

seen = load_seen_ids()
collected_total = 0
drop_stats = defaultdict(int)

with open(JSONL_PATH, "a", encoding="utf-8") as jf:
    for tag in TAGS:
        print(f"\n=== TAG: {tag} ===")
        term_collected = 0
        for url, order_name in tag_order_urls(tag):
            try:
                html_text = fetch(url)
            except Exception as e:
                print("Tag page fetch failed:", url, e)
                sleep(); continue
            sleep()

            pids = extract_post_ids_from_index(html_text)
            if not pids:
                print(f"[{tag}|{order_name}] no post ids on {url}")
                continue

            print(f"[{tag}|{order_name}] {len(pids)} posts on {url}")

            for pid in sorted(pids, key=lambda x: int(x)):
                if pid in seen:
                    continue
                try:
                    thread_meta = parse_thread_page(pid); sleep()
                    post_json   = get_post_json(pid);     sleep()

                    rec = normalize_record(pid, thread_meta, post_json,
                                           origin_tag=tag, order_variant=order_name)
                    if rec:
                        jf.write(json.dumps(rec, ensure_ascii=False) + "\n")
                        jf.flush()
                        collected_total += 1
                        term_collected += 1
                        seen.add(pid)

                        if collected_total % 25 == 0:
                            print(f"Collected {collected_total} items so far...")
                    else:
                        if not (thread_meta.get("question_text") or "").strip():
                            drop_stats["empty_question"] += 1
                        elif not (thread_meta.get("best_answer") or {}).get("text"):
                            drop_stats["no_answer"] += 1
                        else:
                            drop_stats["excluded_or_other"] += 1
                except requests.HTTPError as e:
                    print(f"[warn] HTTP error pid={pid}: {e}")
                    sleep()
                except Exception as e:
                    print(f"[warn] failed pid={pid}: {e}")
                    sleep()

            save_seen_ids(seen)
            sleep()

        print(f"[{tag}] collected={term_collected}")

print(f"\nDone. Collected {collected_total} items → {JSONL_PATH}")
print("Drop stats:", dict(drop_stats))
# Out:
# === TAG: metagenomics ===
# [metagenomics|creation] 46 posts on https://support.bioconductor.org/tag/metagenomics/?order=creation
# Collected 25 items so far...
# [metagenomics|rank] 46 posts on https://support.bioconductor.org/tag/metagenomics/?order=rank
# [metagenomics|votes] 46 posts on https://support.bioconductor.org/tag/metagenomics/?order=votes
# [metagenomics|replies] 46 posts on https://support.bioconductor.org/tag/metagenomics/?order=replies
# [metagenomics] collected=31
#
# === TAG: metagenomeseq ===
# [metagenomeseq|creation] 58 posts on https://support.bioconductor.org/tag/metagenomeseq/?order=creation
# Collected 50 items so far...
# [metagenomeseq|rank] 58 posts on https://support.bioconductor.org/tag/metagenomeseq/?order=rank
# [metagenomeseq|votes] 58 posts on https://support.bioconductor.org/tag/metagenomeseq/?order=votes
# [metagenomeseq|replies] 60 posts on https://support.bioconductor.org/tag/metagenomeseq/?order=replies
# [metagenomeseq] collected=38
#
# === TAG: microbiome ===
# [microbiome|creation] 57 posts on https://support.bioconductor.org/tag/microbiome/?order=creation
# Collected 75 items so far...
# [microbiome|rank] 57 posts on https://support.bioconductor.org/tag/microbiome/?order=rank
# [microbiome|votes] 57 posts on https://support.bioconductor.org/tag/microbiome/?order=votes
# [microbiome|replies] 58 posts on https://support.bioconductor.org/tag/microbiome/?order=replies
# Collected 100 items so far...
# [microbiome] collected=31
#
# === TAG: dada2 ===
# [dada2|creation] 36 posts on https://support.bioconductor.org/tag/dada2/?order=creation
# [dada2|rank] 36 posts on https://support.bioconductor.org/tag/dada2/?order=rank
# [dada2|votes] 36 posts on https://support.bioconductor.org/tag/dada2/?order=votes
# [dada2|replies] 36 posts on https://support.bioconductor.org/tag/dada2/?order=replies
# [dada2] collected=11
#
# === TAG: phyloseq ===
# [phyloseq|creation] 56 posts on https://support.bioconductor.org/tag/phyloseq/?order=creation
# Collected 125 items so far...
# [phyloseq|rank] 56 posts on https://support.bioconductor.org/tag/phyloseq/?order=rank
# [phyloseq|votes] 56 posts on https://support.bioconductor.org/tag/phyloseq/?order=votes
# [phyloseq|replies] 57 posts on https://support.bioconductor.org/tag/phyloseq/?order=replies
# [phyloseq] collected=34
#
# === TAG: metamsdata ===
# [metamsdata|creation] 19 posts on https://support.bioconductor.org/tag/metamsdata/?order=creation
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 1.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 3.2s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 6.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 13.0s then retrying
# [warn] HTTP error pid=9159056: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/
# [metamsdata|rank] 19 posts on https://support.bioconductor.org/tag/metamsdata/?order=rank
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 1.8s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 3.4s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 6.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 12.9s then retrying
# [warn] HTTP error pid=9159056: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/
# [metamsdata|votes] 19 posts on https://support.bioconductor.org/tag/metamsdata/?order=votes
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 1.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 3.3s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 6.5s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 13.2s then retrying
# [warn] HTTP error pid=9159056: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/
# [metamsdata|replies] 19 posts on https://support.bioconductor.org/tag/metamsdata/?order=replies
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 1.9s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 3.5s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 6.8s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/ — sleeping 13.2s then retrying
# [warn] HTTP error pid=9159056: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9159056/
# [metamsdata] collected=4
#
# === TAG: curatedmetagenomicdata ===
# [curatedmetagenomicdata|creation] 28 posts on https://support.bioconductor.org/tag/curatedmetagenomicdata/?order=creation
# Collected 150 items so far...
# [curatedmetagenomicdata|rank] 28 posts on https://support.bioconductor.org/tag/curatedmetagenomicdata/?order=rank
# [curatedmetagenomicdata|votes] 28 posts on https://support.bioconductor.org/tag/curatedmetagenomicdata/?order=votes
# [curatedmetagenomicdata|replies] 28 posts on https://support.bioconductor.org/tag/curatedmetagenomicdata/?order=replies
# [curatedmetagenomicdata] collected=13
#
# === TAG: microarraydata ===
# [microarraydata|creation] 45 posts on https://support.bioconductor.org/tag/microarraydata/?order=creation
# Collected 175 items so far...
# [microarraydata|rank] 45 posts on https://support.bioconductor.org/tag/microarraydata/?order=rank
# [microarraydata|votes] 45 posts on https://support.bioconductor.org/tag/microarraydata/?order=votes
# [microarraydata|replies] 45 posts on https://support.bioconductor.org/tag/microarraydata/?order=replies
# [microarraydata] collected=32
#
# === TAG: 16S ===
# [16S|creation] 17 posts on https://support.bioconductor.org/tag/16S/?order=creation
# [16S|rank] 17 posts on https://support.bioconductor.org/tag/16S/?order=rank
# [16S|votes] 17 posts on https://support.bioconductor.org/tag/16S/?order=votes
# [16S|replies] 17 posts on https://support.bioconductor.org/tag/16S/?order=replies
# [16S] collected=1
#
# === TAG: rnaseq ===
# [rnaseq|creation] 60 posts on https://support.bioconductor.org/tag/rnaseq/?order=creation
# Collected 200 items so far...
# Collected 225 items so far...
# [rnaseq|rank] 60 posts on https://support.bioconductor.org/tag/rnaseq/?order=rank
# [rnaseq|votes] 59 posts on https://support.bioconductor.org/tag/rnaseq/?order=votes
# Collected 250 items so far...
# Collected 275 items so far...
# [rnaseq|replies] 59 posts on https://support.bioconductor.org/tag/rnaseq/?order=replies
# Collected 300 items so far...
# [rnaseq] collected=121
#
# === TAG: sequencing ===
# [sequencing|creation] 58 posts on https://support.bioconductor.org/tag/sequencing/?order=creation
# Collected 325 items so far...
# [sequencing|rank] 58 posts on https://support.bioconductor.org/tag/sequencing/?order=rank
# [sequencing|votes] 60 posts on https://support.bioconductor.org/tag/sequencing/?order=votes
# Collected 350 items so far...
# [sequencing|replies] 60 posts on https://support.bioconductor.org/tag/sequencing/?order=replies
# Collected 375 items so far...
# [sequencing] collected=73
#
# === TAG: fastq ===
# [fastq|creation] 32 posts on https://support.bioconductor.org/tag/fastq/?order=creation
# Collected 400 items so far...
# [fastq|rank] 32 posts on https://support.bioconductor.org/tag/fastq/?order=rank
# [fastq|votes] 32 posts on https://support.bioconductor.org/tag/fastq/?order=votes
# [fastq|replies] 32 posts on https://support.bioconductor.org/tag/fastq/?order=replies
# [fastq] collected=16
#
# === TAG: alignment ===
# [alignment|creation] 56 posts on https://support.bioconductor.org/tag/alignment/?order=creation
# Collected 425 items so far...
# [alignment|rank] 56 posts on https://support.bioconductor.org/tag/alignment/?order=rank
# [alignment|votes] 60 posts on https://support.bioconductor.org/tag/alignment/?order=votes
# Collected 450 items so far...
# [alignment|replies] 60 posts on https://support.bioconductor.org/tag/alignment/?order=replies
# Collected 475 items so far...
# [alignment] collected=77
#
# === TAG: bam ===
# [bam|creation] 60 posts on https://support.bioconductor.org/tag/bam/?order=creation
# Collected 500 items so far...
# [bam|rank] 60 posts on https://support.bioconductor.org/tag/bam/?order=rank
# [bam|votes] 60 posts on https://support.bioconductor.org/tag/bam/?order=votes
# [bam|replies] 60 posts on https://support.bioconductor.org/tag/bam/?order=replies
# [bam] collected=40
#
# === TAG: counts ===
# [counts|creation] 52 posts on https://support.bioconductor.org/tag/counts/?order=creation
# Collected 525 items so far...
# Collected 550 items so far...
# [counts|rank] 52 posts on https://support.bioconductor.org/tag/counts/?order=rank
# [counts|votes] 52 posts on https://support.bioconductor.org/tag/counts/?order=votes
# [counts|replies] 52 posts on https://support.bioconductor.org/tag/counts/?order=replies
# [counts] collected=36
#
# === TAG: vcf ===
# [vcf|creation] 60 posts on https://support.bioconductor.org/tag/vcf/?order=creation
# Collected 575 items so far...
# [vcf|rank] 60 posts on https://support.bioconductor.org/tag/vcf/?order=rank
# [vcf|votes] 60 posts on https://support.bioconductor.org/tag/vcf/?order=votes
# Collected 600 items so far...
# [vcf|replies] 60 posts on https://support.bioconductor.org/tag/vcf/?order=replies
# [vcf] collected=42
#
# === TAG: taxonomy ===
# [taxonomy|creation] 10 posts on https://support.bioconductor.org/tag/taxonomy/?order=creation
# [taxonomy|rank] 10 posts on https://support.bioconductor.org/tag/taxonomy/?order=rank
# [taxonomy|votes] 10 posts on https://support.bioconductor.org/tag/taxonomy/?order=votes
# [taxonomy|replies] 10 posts on https://support.bioconductor.org/tag/taxonomy/?order=replies
# [taxonomy] collected=0
#
# === TAG: clusterprofiler ===
# [clusterprofiler|creation] 60 posts on https://support.bioconductor.org/tag/clusterprofiler/?order=creation
# Collected 625 items so far...
# [clusterprofiler|rank] 60 posts on https://support.bioconductor.org/tag/clusterprofiler/?order=rank
# [clusterprofiler|votes] 59 posts on https://support.bioconductor.org/tag/clusterprofiler/?order=votes
# Collected 650 items so far...
# [clusterprofiler|replies] 59 posts on https://support.bioconductor.org/tag/clusterprofiler/?order=replies
# Collected 675 items so far...
# [clusterprofiler] collected=97
#
# === TAG: annotation ===
# [annotation|creation] 60 posts on https://support.bioconductor.org/tag/annotation/?order=creation
# Collected 700 items so far...
# Collected 725 items so far...
# [annotation|rank] 60 posts on https://support.bioconductor.org/tag/annotation/?order=rank
# [annotation|votes] 60 posts on https://support.bioconductor.org/tag/annotation/?order=votes
# Collected 750 items so far...
# [annotation|replies] 60 posts on https://support.bioconductor.org/tag/annotation/?order=replies
# Collected 775 items so far...
# Collected 800 items so far...
# [annotation] collected=110
#
# === TAG: annotationdbi ===
# [annotationdbi|creation] 51 posts on https://support.bioconductor.org/tag/annotationdbi/?order=creation
# Collected 825 items so far...
# [annotationdbi|rank] 51 posts on https://support.bioconductor.org/tag/annotationdbi/?order=rank
# [annotationdbi|votes] 51 posts on https://support.bioconductor.org/tag/annotationdbi/?order=votes
# Collected 850 items so far...
# [annotationdbi|replies] 57 posts on https://support.bioconductor.org/tag/annotationdbi/?order=replies
# Collected 875 items so far...
# [annotationdbi] collected=71
#
# === TAG: annotationhub ===
# [annotationhub|creation] 55 posts on https://support.bioconductor.org/tag/annotationhub/?order=creation
# Collected 900 items so far...
# [annotationhub|rank] 55 posts on https://support.bioconductor.org/tag/annotationhub/?order=rank
# [annotationhub|votes] 56 posts on https://support.bioconductor.org/tag/annotationhub/?order=votes
# Collected 925 items so far...
# [annotationhub|replies] 57 posts on https://support.bioconductor.org/tag/annotationhub/?order=replies
# [annotationhub] collected=62
#
# === TAG: genomicfeatures ===
# [genomicfeatures|creation] 57 posts on https://support.bioconductor.org/tag/genomicfeatures/?order=creation
# Collected 950 items so far...
# Collected 975 items so far...
# [genomicfeatures|rank] 57 posts on https://support.bioconductor.org/tag/genomicfeatures/?order=rank
# [genomicfeatures|votes] 60 posts on https://support.bioconductor.org/tag/genomicfeatures/?order=votes
# Collected 1000 items so far...
# [genomicfeatures|replies] 60 posts on https://support.bioconductor.org/tag/genomicfeatures/?order=replies
# Collected 1025 items so far...
# [genomicfeatures] collected=105
#
# === TAG: genomicranges ===
# [genomicranges|creation] 60 posts on https://support.bioconductor.org/tag/genomicranges/?order=creation
# Collected 1050 items so far...
# Collected 1075 items so far...
# [genomicranges|rank] 60 posts on https://support.bioconductor.org/tag/genomicranges/?order=rank
# [genomicranges|votes] 59 posts on https://support.bioconductor.org/tag/genomicranges/?order=votes
# Collected 1100 items so far...
# [genomicranges|replies] 59 posts on https://support.bioconductor.org/tag/genomicranges/?order=replies
# Collected 1125 items so far...
# [genomicranges] collected=99
#
# === TAG: iranges ===
# [iranges|creation] 58 posts on https://support.bioconductor.org/tag/iranges/?order=creation
# Collected 1150 items so far...
# Collected 1175 items so far...
# [iranges|rank] 58 posts on https://support.bioconductor.org/tag/iranges/?order=rank
# [iranges|votes] 59 posts on https://support.bioconductor.org/tag/iranges/?order=votes
# Collected 1200 items so far...
# [iranges|replies] 60 posts on https://support.bioconductor.org/tag/iranges/?order=replies
# Collected 1225 items so far...
# [iranges] collected=91
#
# === TAG: ggtree ===
# [ggtree|creation] 36 posts on https://support.bioconductor.org/tag/ggtree/?order=creation
# Collected 1250 items so far...
# [ggtree|rank] 36 posts on https://support.bioconductor.org/tag/ggtree/?order=rank
# [ggtree|votes] 36 posts on https://support.bioconductor.org/tag/ggtree/?order=votes
# [ggtree|replies] 36 posts on https://support.bioconductor.org/tag/ggtree/?order=replies
# [ggtree] collected=16
#
# === TAG: msa ===
# [msa|creation] 59 posts on https://support.bioconductor.org/tag/msa/?order=creation
# Collected 1275 items so far...
# [msa|rank] 59 posts on https://support.bioconductor.org/tag/msa/?order=rank
# [msa|votes] 59 posts on https://support.bioconductor.org/tag/msa/?order=votes
# [msa|replies] 59 posts on https://support.bioconductor.org/tag/msa/?order=replies
# [msa] collected=32
#
# === TAG: featurecounts ===
# [featurecounts|creation] 59 posts on https://support.bioconductor.org/tag/featurecounts/?order=creation
# Collected 1300 items so far...
# [featurecounts|rank] 60 posts on https://support.bioconductor.org/tag/featurecounts/?order=rank
# [featurecounts|votes] 60 posts on https://support.bioconductor.org/tag/featurecounts/?order=votes
# Collected 1325 items so far...
# Collected 1350 items so far...
# [featurecounts|replies] 60 posts on https://support.bioconductor.org/tag/featurecounts/?order=replies
# [featurecounts] collected=80
#
# === TAG: biocparallel ===
# [biocparallel|creation] 54 posts on https://support.bioconductor.org/tag/biocparallel/?order=creation
# Collected 1375 items so far...
# [biocparallel|rank] 54 posts on https://support.bioconductor.org/tag/biocparallel/?order=rank
# [biocparallel|votes] 57 posts on https://support.bioconductor.org/tag/biocparallel/?order=votes
# Collected 1400 items so far...
# [biocparallel|replies] 58 posts on https://support.bioconductor.org/tag/biocparallel/?order=replies
# Collected 1425 items so far...
# [biocparallel] collected=62
#
# === TAG: biocmanager ===
# [biocmanager|creation] 57 posts on https://support.bioconductor.org/tag/biocmanager/?order=creation
# Collected 1450 items so far...
# [biocmanager|rank] 57 posts on https://support.bioconductor.org/tag/biocmanager/?order=rank
# [biocmanager|votes] 57 posts on https://support.bioconductor.org/tag/biocmanager/?order=votes
# [biocmanager|replies] 58 posts on https://support.bioconductor.org/tag/biocmanager/?order=replies
# [biocmanager] collected=32
#
# === TAG: biostrings ===
# [biostrings|creation] 57 posts on https://support.bioconductor.org/tag/biostrings/?order=creation
# Collected 1475 items so far...
# [biostrings|rank] 57 posts on https://support.bioconductor.org/tag/biostrings/?order=rank
# [biostrings|votes] 58 posts on https://support.bioconductor.org/tag/biostrings/?order=votes
# Collected 1500 items so far...
# [biostrings|replies] 59 posts on https://support.bioconductor.org/tag/biostrings/?order=replies
# Collected 1525 items so far...
# [biostrings] collected=71
#
# === TAG: ensemblvep ===
# [ensemblvep|creation] 29 posts on https://support.bioconductor.org/tag/ensemblvep/?order=creation
# [ensemblvep|rank] 29 posts on https://support.bioconductor.org/tag/ensemblvep/?order=rank
# [ensemblvep|votes] 29 posts on https://support.bioconductor.org/tag/ensemblvep/?order=votes
# [ensemblvep|replies] 29 posts on https://support.bioconductor.org/tag/ensemblvep/?order=replies
# [ensemblvep] collected=10
#
# === TAG: ensembl ===
# [ensembl|creation] 57 posts on https://support.bioconductor.org/tag/ensembl/?order=creation
# Collected 1550 items so far...
# [ensembl|rank] 57 posts on https://support.bioconductor.org/tag/ensembl/?order=rank
# [ensembl|votes] 60 posts on https://support.bioconductor.org/tag/ensembl/?order=votes
# Collected 1575 items so far...
# [ensembl|replies] 60 posts on https://support.bioconductor.org/tag/ensembl/?order=replies
# [ensembl] collected=60
#
# === TAG: genomes ===
# [genomes|creation] 60 posts on https://support.bioconductor.org/tag/genomes/?order=creation
# Collected 1600 items so far...
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 1.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 3.5s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 6.4s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 12.8s then retrying
# [warn] HTTP error pid=9160674: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/
# [genomes|rank] 60 posts on https://support.bioconductor.org/tag/genomes/?order=rank
# Collected 1625 items so far...
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 1.7s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 3.3s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 6.6s then retrying
# [retry] HTTPError: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/ — sleeping 13.0s then retrying
# [warn] HTTP error pid=9160674: 404 Client Error: Not Found for url: https://support.bioconductor.org/p/9160674/
# [genomes|votes] 60 posts on https://support.bioconductor.org/tag/genomes/?order=votes
# Collected 1650 items so far...
# [genomes|replies] 60 posts on https://support.bioconductor.org/tag/genomes/?order=replies
# [genomes] collected=64
#
# === TAG: genomicfiles ===
# [genomicfiles|creation] 21 posts on https://support.bioconductor.org/tag/genomicfiles/?order=creation
# [genomicfiles|rank] 21 posts on https://support.bioconductor.org/tag/genomicfiles/?order=rank
# [genomicfiles|votes] 21 posts on https://support.bioconductor.org/tag/genomicfiles/?order=votes
# [genomicfiles|replies] 21 posts on https://support.bioconductor.org/tag/genomicfiles/?order=replies
# [genomicfiles] collected=7
#
# === TAG: genomicalignments ===
# [genomicalignments|creation] 59 posts on https://support.bioconductor.org/tag/genomicalignments/?order=creation
# Collected 1675 items so far...
# [genomicalignments|rank] 59 posts on https://support.bioconductor.org/tag/genomicalignments/?order=rank
# [genomicalignments|votes] 60 posts on https://support.bioconductor.org/tag/genomicalignments/?order=votes
# Collected 1700 items so far...
# [genomicalignments|replies] 59 posts on https://support.bioconductor.org/tag/genomicalignments/?order=replies
# [genomicalignments] collected=52
#
# === TAG: reads ===
# [reads|creation] 18 posts on https://support.bioconductor.org/tag/reads/?order=creation
# Collected 1725 items so far...
# [reads|rank] 18 posts on https://support.bioconductor.org/tag/reads/?order=rank
# [reads|votes] 18 posts on https://support.bioconductor.org/tag/reads/?order=votes
# [reads|replies] 18 posts on https://support.bioconductor.org/tag/reads/?order=replies
# [reads] collected=4
#
# === TAG: flow cytometry ===
# [flow cytometry|creation] 60 posts on https://support.bioconductor.org/tag/flow cytometry/?order=creation
# Collected 1750 items so far...
# [flow cytometry|rank] 60 posts on https://support.bioconductor.org/tag/flow cytometry/?order=rank
# [flow cytometry|votes] 60 posts on https://support.bioconductor.org/tag/flow cytometry/?order=votes
# [flow cytometry|replies] 60 posts on https://support.bioconductor.org/tag/flow cytometry/?order=replies
# [flow cytometry] collected=33
#
# === TAG: deconvolution ===
# [deconvolution|creation] 21 posts on https://support.bioconductor.org/tag/deconvolution/?order=creation
# [deconvolution|rank] 21 posts on https://support.bioconductor.org/tag/deconvolution/?order=rank
# [deconvolution|votes] 21 posts on https://support.bioconductor.org/tag/deconvolution/?order=votes
# [deconvolution|replies] 21 posts on https://support.bioconductor.org/tag/deconvolution/?order=replies
# [deconvolution] collected=4
#
# === TAG: normalization ===
# [normalization|creation] 60 posts on https://support.bioconductor.org/tag/normalization/?order=creation
# Collected 1775 items so far...
# Collected 1800 items so far...
# [normalization|rank] 60 posts on https://support.bioconductor.org/tag/normalization/?order=rank
# [normalization|votes] 59 posts on https://support.bioconductor.org/tag/normalization/?order=votes
# Collected 1825 items so far...
# [normalization|replies] 58 posts on https://support.bioconductor.org/tag/normalization/?order=replies
# Collected 1850 items so far...
# [normalization] collected=109
#
# === TAG: filtering ===
# [filtering|creation] 40 posts on https://support.bioconductor.org/tag/filtering/?order=creation
# Collected 1875 items so far...
# [filtering|rank] 40 posts on https://support.bioconductor.org/tag/filtering/?order=rank
# [filtering|votes] 40 posts on https://support.bioconductor.org/tag/filtering/?order=votes
# [filtering|replies] 40 posts on https://support.bioconductor.org/tag/filtering/?order=replies
# [filtering] collected=26
#
# === TAG: kegg ===
# [kegg|creation] 59 posts on https://support.bioconductor.org/tag/kegg/?order=creation
# Collected 1900 items so far...
# [kegg|rank] 59 posts on https://support.bioconductor.org/tag/kegg/?order=rank
# [kegg|votes] 59 posts on https://support.bioconductor.org/tag/kegg/?order=votes
# Collected 1925 items so far...
# [kegg|replies] 60 posts on https://support.bioconductor.org/tag/kegg/?order=replies
# Collected 1950 items so far...
# [kegg] collected=53
#
# === TAG: pathways ===
# [pathways|creation] 58 posts on https://support.bioconductor.org/tag/pathways/?order=creation
# [pathways|rank] 58 posts on https://support.bioconductor.org/tag/pathways/?order=rank
# [pathways|votes] 58 posts on https://support.bioconductor.org/tag/pathways/?order=votes
# Collected 1975 items so far...
# [pathways|replies] 60 posts on https://support.bioconductor.org/tag/pathways/?order=replies
# Collected 2000 items so far...
# [pathways] collected=61
#
# === TAG: visualization ===
# [visualization|creation] 60 posts on https://support.bioconductor.org/tag/visualization/?order=creation
# Collected 2025 items so far...
# [visualization|rank] 60 posts on https://support.bioconductor.org/tag/visualization/?order=rank
# [visualization|votes] 60 posts on https://support.bioconductor.org/tag/visualization/?order=votes
# [visualization|replies] 60 posts on https://support.bioconductor.org/tag/visualization/?order=replies
# Collected 2050 items so far...
# [visualization] collected=48
#
# Done. Collected 2059 items → ../04-output/raw/bioconductor/bioconductor_metagenomics_tag.jsonl
# Drop stats: {'no_answer': 1947}

# %%
# ========================
# Emit CSV snapshot
# ========================
field_order = [
    "source","post_id","url","title","question","answer","accepted",
    "score","tags_site","created_at","has_accepted","view_count","topic_labels",
    "search_query","crawl_tag","crawl_order"
]

rows = []
if JSONL_PATH.exists():
    with open(JSONL_PATH, "r", encoding="utf-8") as jf:
        for line in jf:
            obj = json.loads(line)
            obj["topic_labels"] = ";".join(obj.get("topic_labels", []))
            tags = obj.get("tags_site", [])
            if isinstance(tags, list):
                obj["tags_site"] = ";".join(tags)
            rows.append({k: obj.get(k, "") for k in field_order})

    with open(CSV_PATH, "w", encoding="utf-8", newline="") as cf:
        w = csv.DictWriter(cf, fieldnames=field_order)
        w.writeheader()
        for r in rows:
            w.writerow(r)

    print(f"Wrote CSV: {CSV_PATH} (rows={len(rows)})")
else:
    print(f"No JSONL at {JSONL_PATH}, skipping CSV.")
# Out:
# Wrote CSV: ../04-output/raw/bioconductor/bioconductor_metagenomics_tag.csv (rows=2059)
